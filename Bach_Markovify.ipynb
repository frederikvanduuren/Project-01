# %% [markdown]
# <a href="https://colab.research.google.com/github/frederikvanduuren/Project-01/blob/master/Bach_Markovify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Creating Bach Music using Markov Chain Generator

# %% [markdown]
# The basic idea was to see NOTES as words...

# %%
pip install markovify

# %% [markdown]
# Importing pandas & markovify

# %%
import pandas as pd # data processing, CSV file I/O
import markovify #Markov Chain Generator

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aaeb8eea-332e-474b-8812-26f3d7eec2e9" name="files[]" multiple disabled />
#      <output id="result-aaeb8eea-332e-474b-8812-26f3d7eec2e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
inp = pd.read_csv('Bach Prelude 1 C Maj.csv')
inp.head(10)
# Out:
#      C4 E4 G4 C5 E5 G4 C5 E5
# 0    C4 D4 A4 D5 F5 A4 D5 F5
# 1    B3 D4 G4 D5 F5 G4 D5 F5
# 2    C4 E4 A4 E5 A5 A4 E5 A5
# 3  C4 D4 F#4 A4 D5 F#4 A4 D5
# 4    B3 D4 G4 D5 G5 G4 B4 G5
# 5    B3 C4 E4 G4 C5 E4 G4 C5
# 6    A3 C4 E4 G4 C5 E4 G4 C5
# 7   F#3 A3 D4 A4 C5 D4 A4 C5

# %% [markdown]
# Markovify works best with large, well-punctuated texts. If your text does not use `.`s to delineate sentences, put each sentence on a newline, and use the `markovify.NewlineText` class instead of `markovify.Text` class

# %%
text_model = markovify.NewlineText(inp)

# %% [markdown]
# Print eitgh randomly-generated sentences

# %%
for i in range(8):
    print(text_model.make_sentence())
# Out:
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5

# %% [markdown]
# Print eight randomly-generated sentences of no more than 48 characters

# %%
for i in range(8):
    print(text_model.make_short_sentence(48))
# Out:
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5
# C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5

# %% [markdown]
# It definity produces some new music... now time to put this music into some MIDI file & LISTEN!
#
# `C4 E4 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5 G4 C5 E5`

# %%
# !apt install fluidsynth
# !cp /usr/share/sounds/sf2/FluidR3_GM.sf2 ./font.sf2
# !pip install midi2audio
from midi2audio import FluidSynth
from IPython.display import Audio

FluidSynth("font.sf2").midi_to_audio('Bach.mid', 'Bach.wav')
Audio("Bach.wav")
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fluidsynth is already the newest version (1.1.9-1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# ...
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
